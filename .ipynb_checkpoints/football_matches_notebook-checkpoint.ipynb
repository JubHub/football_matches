# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('football_matches.csv')

# %%
df.head(2)
# Out:
#    season        date  league_id          league      team1  \
# 0    2016  2016-08-12       1843  French Ligue 1     Bastia
# 1    2016  2016-08-12       1843  French Ligue 1  AS Monaco
#
#                  team2   spi1   spi2   prob1   prob2  ...  proj_score1  \
# 0  Paris Saint-Germain  51.16  85.68  0.0463  0.8380  ...         0.91
# 1             Guingamp  68.85  56.48  0.5714  0.1669  ...         1.82
#
#    proj_score2  score1  score2   xg1   xg2  nsxg1  nsxg2  adj_score1  \
# 0         2.36     0.0     1.0  0.97  0.63   0.43   0.45         0.0
# 1         0.86     2.0     2.0  2.45  0.77   1.75   0.42         2.1
#
#    adj_score2
# 0        1.05
# 1        2.10
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2'],
#       dtype='object')

# %%
df.season.value_counts()
# Out:
# 2018    5385
# 2017    4800
# 2019    4528
# 2016    2118
# 2020      26
# Name: season, dtype: int64

# %%
df.describe()
# Out:
#              season     league_id          spi1          spi2         prob1  \
# count  16857.000000  16857.000000  16857.000000  16857.000000  16857.000000
# mean    2017.735659   2205.177137     54.024726     53.927479      0.457886
# std        0.996139    877.527954     17.023377     17.040088      0.157415
# min     2016.000000   1818.000000     15.290000     14.950000      0.028100
# 25%     2017.000000   1846.000000     40.770000     40.630000      0.364400
# 50%     2018.000000   1869.000000     52.890000     52.810000      0.449200
# 75%     2019.000000   2105.000000     66.570000     66.440000      0.540800
# max     2020.000000   5641.000000     96.570000     96.780000      0.977500
#
#               prob2       probtie   proj_score1   proj_score2        score1  \
# count  16857.000000  16857.000000  16857.000000  16857.000000  16857.000000
# mean       0.288974      0.253141      1.532360      1.136262      1.546657
# std        0.140406      0.046547      0.416358      0.407973      1.277093
# min        0.003200      0.000000      0.250000      0.200000      0.000000
# 25%        0.201900      0.236800      1.270000      0.890000      1.000000
# 50%        0.273700      0.263400      1.470000      1.090000      1.000000
# 75%        0.354600      0.282700      1.720000      1.330000      2.000000
# max        0.880100      0.357700      4.030000      3.430000     10.000000
#
#              score2           xg1           xg2         nsxg1         nsxg2  \
# count  16857.000000  16857.000000  16857.000000  16857.000000  16857.000000
# mean       1.171739      1.508379      1.163909      1.416101      1.131911
# std        1.141138      0.832046      0.730613      0.653270      0.568924
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.890000      0.620000      0.960000      0.730000
# 50%        1.000000      1.380000      1.030000      1.320000      1.040000
# 75%        2.000000      1.980000      1.550000      1.760000      1.430000
# max        9.000000      7.070000      6.200000      6.890000      5.920000
#
#          adj_score1    adj_score2
# count  16857.000000  16857.000000
# mean       1.546275      1.185284
# std        1.245118      1.124998
# min        0.000000      0.000000
# 25%        1.050000      0.000000
# 50%        1.050000      1.050000
# 75%        2.100000      2.100000
# max        9.150000      7.930000

# %%
df.xg1.hist()

# %%
df.spi1.hist()

# %%
df.boxplot(column = ['score1', 'xg1', 'nsxg1', 'proj_score1', 'adj_score1'])

# %%
df[['score1', 'xg1', 'nsxg1', 'proj_score1', 'adj_score1']].corr()
# Out:
#                score1       xg1     nsxg1  proj_score1  adj_score1
# score1       1.000000  0.559389  0.216383     0.346288    0.990636
# xg1          0.559389  1.000000  0.554794     0.432978    0.546100
# nsxg1        0.216383  0.554794  1.000000     0.509796    0.205753
# proj_score1  0.346288  0.432978  0.509796     1.000000    0.341660
# adj_score1   0.990636  0.546100  0.205753     0.341660    1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(df[['score1', 'xg1', 'nsxg1', 'proj_score1', 'adj_score1']].corr(), vmax = .3, center = 0, cmap = cmap, 
            square = True, linewidth = .5, cbar_kws = {"shrink": .5})

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2'],
#       dtype='object')

# %%
df_cat = df[['league', 'season', 'team1']]

# %%
for i in df_cat.columns: 
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for league: total = 18
# graph for season: total = 5
# graph for team1: total = 419
