# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('football_matches.csv')

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2'],
#       dtype='object')

# %%
df.season.value_counts()
# Out:
# 2018    5385
# 2017    4800
# 2019    4528
# Name: season, dtype: int64

# %%
df.describe()
# Out:
#              season     league_id          spi1          spi2         prob1  \
# count  14713.000000  14713.000000  14713.000000  14713.000000  14713.000000
# mean    2017.981513   2240.810168     52.569368     52.463173      0.457283
# std        0.796052    930.447440     16.909093     16.915176      0.153084
# min     2017.000000   1818.000000     15.290000     14.950000      0.034600
# 25%     2017.000000   1846.000000     39.570000     39.490000      0.365500
# 50%     2018.000000   1948.000000     50.680000     50.590000      0.448800
# 75%     2019.000000   2105.000000     64.500000     64.480000      0.539100
# max     2019.000000   5641.000000     95.750000     95.510000      0.956100
#
#               prob2       probtie   proj_score1   proj_score2        score1  \
# count  14713.000000  14713.000000  14713.000000  14713.000000  14713.000000
# mean       0.288850      0.253867      1.529528      1.136230      1.536396
# ...

# %%
df.spi1.hist()

# %%
df.boxplot(column = ['score1', 'xg1', 'nsxg1', 'proj_score1', 'adj_score1'])

# %%
df[['score1', 'xg1', 'nsxg1', 'proj_score1', 'adj_score1']].corr()
# Out:
#                score1       xg1     nsxg1  proj_score1  adj_score1
# score1       1.000000  0.558577  0.206129     0.338093    0.990362
# xg1          0.558577  1.000000  0.547476     0.420538    0.544360
# nsxg1        0.206129  0.547476  1.000000     0.495986    0.194932
# proj_score1  0.338093  0.420538  0.495986     1.000000    0.333350
# adj_score1   0.990362  0.544360  0.194932     0.333350    1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(df[['score1', 'xg1', 'nsxg1', 'proj_score1', 'adj_score1']].corr(), vmax = .3, center = 0, cmap = cmap, 
            square = True, linewidth = .5, cbar_kws = {"shrink": .5})

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2'],
#       dtype='object')

# %%
df_cat = df[['league', 'season', 'team1', 'team2']]

# %%
for i in df_cat.columns: 
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for league: total = 18
# graph for season: total = 3
# graph for team1: total = 411
# graph for team2: total = 411

# %%
# top 20

for i in df_cat[['team1', 'team2']].columns: 
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for team1: total = 20
# graph for team2: total = 20

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2'],
#       dtype='object')

# %%
pd.pivot_table(df, index = ['season', 'league'], values = 'spi1')
# Out:
#                                                       spi1
# season league
# 2017   Argentina Primera Division                45.351326
#        Barclays Premier League                   64.690684
#        Brasileiro Série A                        48.521947
#        English League Championship               38.044514
#        French Ligue 1                            59.605079
#        German 2. Bundesliga                      39.054542
#        German Bundesliga                         69.247516
#        Italy Serie A                             63.298395
#        Major League Soccer                       32.345090
#        Mexican Primera Division Torneo Apertura  42.762866
#        Mexican Primera Division Torneo Clausura  42.411024
#        Portuguese Liga                           46.915016
#        Spanish Primera Division                  71.279947
#        UEFA Champions League                     76.692177
#        UEFA Europa League                        60.668585
# ...

# %%
pd.pivot_table(df, index = 'league', values = 'spi1').sort_values('spi1', ascending = False)
# Out:
#                                                spi1
# league
# UEFA Champions League                     78.406275
# Spanish Primera Division                  73.308369
# Barclays Premier League                   69.802634
# German Bundesliga                         68.930756
# Italy Serie A                             65.109498
# UEFA Europa League                        62.865422
# French Ligue 1                            61.237575
# Brasileiro Série A                        50.665650
# Portuguese Liga                           48.606346
# Mexican Primera Division Torneo Apertura  45.544147
# English League Championship               45.212802
# Mexican Primera Division Torneo Clausura  45.114171
# Argentina Primera Division                44.878067
# Chinese Super League                      43.618065
# German 2. Bundesliga                      36.081355
# Major League Soccer                       35.909811
# Australian A-League                       32.246902
# ...

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['season','league'], values = 'spi1').sort_values('season', ascending = False)
# Out:
#                                                       spi1
# season league
# 2019   UEFA Europa League                        63.542692
#        German Bundesliga                         70.289540
#        Argentina Primera Division                43.755471
#        Australian A-League                       29.128017
#        Barclays Premier League                   74.459653
#        Brasileiro Série A                        52.080676
#        Chinese Super League                      42.935314
#        English League Championship               49.196329
#        German 2. Bundesliga                      34.449421
#        French Ligue 1                            61.829427
#        Italy Serie A                             65.336758
#        Italy Serie B                             25.069353
#        Major League Soccer                       39.505629
#        Mexican Primera Division Torneo Apertura  45.920000
#        Mexican Primera Division Torneo Clausura  45.889444
# ...

# %%
pd.pivot_table(df, index = ['season','league'], values = 'spi1', aggfunc = 'count').sort_values('season', ascending = False)
# Out:
#                                                  spi1
# season league
# 2019   UEFA Europa League                         182
#        German Bundesliga                          261
#        Argentina Primera Division                 276
#        Australian A-League                        116
#        Barclays Premier League                    288
#        Brasileiro Série A                         355
#        Chinese Super League                       239
#        English League Championship                444
#        German 2. Bundesliga                       259
#        French Ligue 1                             279
#        Italy Serie A                              256
#        Italy Serie B                              278
#        Major League Soccer                        421
#        Mexican Primera Division Torneo Apertura   185
#        Mexican Primera Division Torneo Clausura    90
#        Portuguese Liga                            221
# ...

# %%
pd.pivot_table(df[df.league == 'UEFA Champions League'], index = ['season', 'team1'], values = 'spi1').sort_values('spi1', ascending = False)
# Out:
#                                  spi1
# season team1
# 2019   Manchester City      95.426667
# 2018   Manchester City      94.028000
# 2017   Barcelona            93.930000
# 2019   Bayern Munich        92.693333
# 2017   Bayern Munich        92.636667
# 2018   Barcelona            92.518333
# 2019   Liverpool            92.502500
# 2017   Real Madrid          92.142857
# 2018   Bayern Munich        91.580000
#        Liverpool            91.565000
# 2017   Paris Saint-Germain  91.195000
#        Manchester City      90.520000
# 2018   Paris Saint-Germain  90.145000
#        Real Madrid          89.965000
# 2019   Paris Saint-Germain  89.307500
#        Barcelona            89.126667
# 2018   Juventus             88.054000
# 2019   Real Madrid          88.005000
# 2017   Juventus             87.072000
# 2019   Juventus             86.750000
# 2018   Atletico Madrid      86.652500
# 2017   Borussia Dortmund    86.190000
# 2019   Chelsea              85.275000
# ...

# %%
df.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'score1', 'score2', 'xg1', 'xg2', 'nsxg1', 'nsxg2', 'adj_score1',
#        'adj_score2'],
#       dtype='object')

# %%
df_pivots = pd.DataFrame(df, columns = ['season', 'league', 'team1', 'team2', 'spi1'])

# %%
df_pivots.columns
# Out:
# Index(['season', 'league', 'team1', 'team2', 'spi1'], dtype='object')

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index = i, values = 'spi1').sort_values('spi1', ascending = False))
# Out:
# season
#              spi1
# season
# 2018    53.240607
# 2017    52.324452
# 2019    52.030713
# league
#                                                spi1
# league
# UEFA Champions League                     78.406275
# Spanish Primera Division                  73.308369
# Barclays Premier League                   69.802634
# German Bundesliga                         68.930756
# Italy Serie A                             65.109498
# UEFA Europa League                        62.865422
# French Ligue 1                            61.237575
# Brasileiro Série A                        50.665650
# Portuguese Liga                           48.606346
# Mexican Primera Division Torneo Apertura  45.544147
# English League Championship               45.212802
# Mexican Primera Division Torneo Clausura  45.114171
# Argentina Primera Division                44.878067
# Chinese Super League                      43.618065
# German 2. Bundesliga                      36.081355
# ...

# %%
pd.pivot_table(df_pivots, index = 'league', columns = 'season', values = 'spi1')
# Out:
# season                                         2017       2018       2019
# league
# Argentina Primera Division                45.351326  45.282431  43.755471
# Australian A-League                             NaN  34.849712  29.128017
# Barclays Premier League                   64.690684  71.385053  74.459653
# Brasileiro Série A                        48.521947  51.487421  52.080676
# Chinese Super League                            NaN  44.892891  42.935314
# English League Championship               38.044514  49.200000  49.196329
# French Ligue 1                            59.605079  62.435526  61.829427
# German 2. Bundesliga                      39.054542  34.489444  34.449421
# German Bundesliga                         69.247516  67.455033  70.289540
# Italy Serie A                             63.298395  66.767500  65.336758
# Italy Serie B                                   NaN  27.243994  25.069353
# Major League Soccer                       32.345090  35.615613  39.505629
# ...
